# %% [markdown]
# <a href="https://colab.research.google.com/github/AnandhPaulswamy/MathForDataScience/blob/main/Chapter1_Math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Essential Math For Data Science
#
# Primary library used in this book - numpy, scipy, sympy and sklearn.
# NumPy - Numerical python (multi D Array, matrices)
# SciPy - Scientific Python (algebra, integration, signal & image processing)
# SymPy - Symbolic Python (computer algebra system)
# sklearn - scikit-learn (Machine Learning)

# %%
pip install numpy scipy sympy scikit-learn
